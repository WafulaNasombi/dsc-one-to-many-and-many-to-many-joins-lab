# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge of one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# * Explain one-to-many and many-to-many joins as well as implications for the size of query results
# * Query data using one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='https://curriculum-content.s3.amazonaws.com/data-science/images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database
#
# Include the relevant imports, then connect to the database located at `data.sqlite`.

# %%
# Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')

# %% [markdown]
# ## Employees and Their Offices (a One-to-One Join)
#
# Select all of the employees including their first name and last name along with the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
# Your code here
q= (
    """
    SELECT e.firstName, e.lastName,o.city, o.state
    FROM employees as e
    JOIN offices as o 
    ON e.officeCode = o.officeCode
    GROUP BY e.firstName, e.lastName
    ORDER BY e.firstName
    """
)

pd.read_sql(q,conn)
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and Their Orders (a One-to-Many Join)
#
# Select all of the customer contacts (first and last names) along with details for each of the customers' order numbers, order dates, and statuses.

# %%
# Your code here
q =(
    """
    SELECT c.contactFirstName AS FirstName, c.contactLastName AS LastName, o.OrderNumber AS OrderNumber, o.orderDate AS OrderDate, o.status AS Status
    FROM customers AS c
    JOIN orders AS o
    USING(customerNumber)
    """
)
pd.read_sql(q,conn)
# Out:
#     FirstName LastName  OrderNumber   OrderDate     Status
# 0     Carine   Schmitt        10123  2003-05-20    Shipped
# 1     Carine   Schmitt        10298  2004-09-27    Shipped
# 2     Carine   Schmitt        10345  2004-11-25    Shipped
# 3        Jean     King        10124  2003-05-21    Shipped
# 4        Jean     King        10278  2004-08-06    Shipped
# ..        ...      ...          ...         ...        ...
# 321   Valarie   Franco        10243  2004-04-26    Shipped
# 322      Tony  Snowden        10138  2003-07-07    Shipped
# 323      Tony  Snowden        10179  2003-11-11  Cancelled
# 324      Tony  Snowden        10360  2004-12-16    Shipped
# 325      Tony  Snowden        10399  2005-04-01    Shipped
#
# [326 rows x 5 columns]

# %% [markdown]
# ## Customers and Their Payments (Another One-to-Many Join)
#
# Select all of the customer contacts (first and last names) along with details for each of the customers' payment amounts and date of payment. Sort these results in descending order by the payment amount.

# %%
# Your code here
q=(
    """
    SELECT c.contactFirstName AS FirstName, c.contactLastName AS LastName, p.amount AS AmountPayment, p.paymentDate AS PaymentDate
    FROM customers c 
    JOIN payments p 
    USING(customerNumber)
    """
    
)
pd.read_sql(q,conn)
# Out:
#     FirstName LastName  AmountPayment PaymentDate
# 0     Carine   Schmitt       14571.44  2003-06-05
# 1     Carine   Schmitt        6066.78  2004-10-19
# 2     Carine   Schmitt        1676.14  2004-12-18
# 3        Jean     King       32641.98  2003-06-06
# 4        Jean     King       33347.88  2004-08-20
# ..        ...      ...            ...         ...
# 268   Valarie   Franco       59265.14  2003-12-26
# 269   Valarie   Franco        6276.60  2004-05-14
# 270      Tony  Snowden       32077.44  2003-07-16
# 271      Tony  Snowden       52166.00  2004-12-31
# 272      Tony  Snowden       30253.75  2005-05-25
#
# [273 rows x 4 columns]

# %% [markdown]
# ## Orders, Order Details, and Product Details (a Many-to-Many Join)

# %% [markdown]
# Select all of the customer contacts (first and last names) along with the product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# > Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries that can make complex queries such as this much simpler!

# %%
# Your code here
q=(
    """
    SELECT c.contactFirstName AS FirstName, c.contactLastName AS LastName, pr.productName AS ProductName, od.quantityOrdered AS QuantityOrdered, o.orderDate AS OrderDate
    FROM customers c 
    JOIN orders AS o ON c.customerNumber = o.customerNumber
    JOIN orderDetails AS od ON o.orderNumber = od.orderNumber
    JOIN products AS pr ON od.productCode = pr.productCode
    GROUP BY c.contactFirstName, c.contactLastName
    ORDER BY c.contactFirstName
    
    """
    
)
pd.read_sql(q,conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# OperationalError: near "AS": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[10], line 14
#       1 # Your code here
#       2 q=(
#       3     """
#       4     SELECT c.contactFirstName AS FirstName, c.contactLastName AS LastName, pr.productName AS ProductName, od.quantityOrdered AS QuantityOrdered, o.orderDate AS OrderDate
#    (...)
#      12
#      13 )
# ---> 14 pd.read_sql(q,conn)
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py:2736, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2725 def read_query(
#    2726     self,
#    2727     sql,
#    (...)
#    2734     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2735 ) -> DataFrame | Iterator[DataFrame]:
# -> 2736     cursor = self.execute(sql, params)
#    2737     columns = [col_desc[0] for col_desc in cursor.description]
#    2739     if chunksize is not None:
#
# File c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py:2684, in SQLiteDatabase.execute(self, sql, params)
#    2681     raise ex from inner_exc
#    2683 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2684 raise ex from exc
#
# DatabaseError: Execution failed on sql '
#     SELECT c.contactFirstName AS FirstName, c.contactLastName AS LastName, pr.productName AS ProductName, od.quantityOrdered AS QuantityOrdered, o.orderDate AS OrderDate
#     FROM customers c
#     JOIN orders AS o ON c.customerNumber = o.customerNumber
#     JOIN orderDetails AS od ON o.orderNumber = od.orderNumber
#     JOIN products AS pr ON od.productCode = pr.productCode
#     GROUP BY c.contactFirstName AS FirstName, c.contactLastName AS LastName
#     ORDER BY c.contactFirstName AS FirstName
#     ': near "AS": syntax error

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge of one-to-many and many-to-many relationships!
